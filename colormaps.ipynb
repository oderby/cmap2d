# %%
import sys
import os
import inspect

PACKAGE_PARENT = '..'
SCRIPT_DIR = os.path.realpath(os.path.dirname(inspect.getfile(inspect.currentframe())))
PARENT_PATH = os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT))
if sys.path.count(PARENT_PATH) == 0:
    sys.path.append(PARENT_PATH)
print(sys.path)

from cmap2d.colormap import *
from cmap2d.util import make_tests, run_tests
# Out:
# ['', '/usr/lib/python35.zip', '/usr/lib/python3.5', '/usr/lib/python3.5/plat-x86_64-linux-gnu', '/usr/lib/python3.5/lib-dynload', '/home/ocderby/.local/lib/python3.5/site-packages', '/usr/local/lib/python3.5/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.5/dist-packages/IPython/extensions', '/home/ocderby/.ipython', '/home/ocderby/Documents/code']

# %%
# %matplotlib inline
# %load_ext autoreload
% autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
samples = make_tests(45)
run_tests(SimplexColorMap, samples, scale=2)
# Out:
# plotting SimplexColorMap shape 0
# plotting SimplexColorMap shape 1
# plotting SimplexColorMap shape 2
# plotting SimplexColorMap shape 3

# %%
samples = make_tests(45)
run_tests(AvgColorMap, samples, scale=2)
# Out:
# plotting AvgColorMap shape 0
# plotting AvgColorMap shape 1
# plotting AvgColorMap shape 2
# plotting AvgColorMap shape 3

# %%
samples = make_tests(45)
run_tests(TernaryColorMap, samples, scale=2)
# Out:
# plotting TernaryColorMap shape 0
# plotting TernaryColorMap shape 1
# plotting TernaryColorMap shape 2
# plotting TernaryColorMap shape 3

# %%
samples = make_tests(45)
run_tests(ProjectionColorMap, samples, scale=5)
# Out:
# plotting ProjectionColorMap shape 0
# plotting ProjectionColorMap shape 1
# plotting ProjectionColorMap shape 2
# plotting ProjectionColorMap shape 3

# %%
samples = make_tests(45)
run_tests(ColorMapCrude, samples, scale=5)
# Out:
# plotting ColorMapCrude shape 0
# plotting ColorMapCrude shape 1
# plotting ColorMapCrude shape 2
# plotting ColorMapCrude shape 3

# %%
samples = make_tests(45)
run_tests(ColorMap, samples, scale=5)
# Out:
# plotting ColorMap shape 0
# plotting ColorMap shape 1
# plotting ColorMap shape 2
# plotting ColorMap shape 3

# %%
samples = make_tests(45)
run_tests(ColorMap2, samples, scale=5)
# Out:
# plotting ColorMap2 shape 0
# plotting ColorMap2 shape 1
# plotting ColorMap2 shape 2
# plotting ColorMap2 shape 3

# %%
samples = make_tests(45)
classes = [SimplexColorMap, TernaryColorMap, ProjectionColorMap, AvgColorMap,
           ColorMapCrude, ColorMap, ColorMap2]
run_tests(classes, samples, scale=2)
# Out:
# plotting SimplexColorMap shape 0
# plotting SimplexColorMap shape 1
# plotting SimplexColorMap shape 2
# plotting SimplexColorMap shape 3
# plotting TernaryColorMap shape 0
# plotting TernaryColorMap shape 1
# plotting TernaryColorMap shape 2
# plotting TernaryColorMap shape 3
# plotting ProjectionColorMap shape 0
# plotting ProjectionColorMap shape 1
# plotting ProjectionColorMap shape 2
# plotting ProjectionColorMap shape 3
# plotting AvgColorMap shape 0
# plotting AvgColorMap shape 1
# plotting AvgColorMap shape 2
# plotting AvgColorMap shape 3
# plotting ColorMapCrude shape 0
# plotting ColorMapCrude shape 1
# plotting ColorMapCrude shape 2
# plotting ColorMapCrude shape 3
# plotting ColorMap shape 0
# plotting ColorMap shape 1
# plotting ColorMap shape 2
# plotting ColorMap shape 3
# plotting ColorMap2 shape 0
# plotting ColorMap2 shape 1
# plotting ColorMap2 shape 2
# plotting ColorMap2 shape 3
